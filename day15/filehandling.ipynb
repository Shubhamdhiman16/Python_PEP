# %%
file = open("data.txt", "r")
print(file.read())
file.close()
# Out:
# Hello Python
# hloooooooooooooo

# %%
file = open("data.txt", "w")
file.write("Hello Python\n")
file.write("hloooooooooooooo")
file.close()

# %%
file = open("data.txt", "a")
file.write("\nWelcome")
file.close()

# %%
file = open("data.txt", "r")
print(file.readline())
file.close()
# Out:
# Hello Python
