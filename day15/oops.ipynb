# %%
class Student:
    collage = "LPU"

    def __init__(self,name,age):
        self.name = name
        self.age = age


        def display(self):
            print(self.name, self.age , self.collage)

            s1 = Student("Rahul",12)
            s2 = Student("Amit", 20)

            s1.display()
            s2.display()
