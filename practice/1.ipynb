# %%
P = int(input("enter a numner for P: "))
R = int(input("enter a number for R: "))
T = int(input("enter a number for T: "))

SI = (P * R * T)/100
print("SI is : " , SI)
# Out:
# SI is :  0.12

# %%
name = input("enter name : ")
age = int(input("enter age : "))

print("my name is ",name , " and my age is" , age)
# Out:
# my name is  shubham  and my age is 19

# %%
a = int(input("enter a numner for a: "))
b = int(input("enter a numner for b: "))
c = int(input("enter a numner for c: "))

average = (a + b + c) / 3

print(average)
# Out:
# 2.6666666666666665
