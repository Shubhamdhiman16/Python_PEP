# %%
import pandas as pd

df_cvs = pd.read_csv(r"C:\Users\dhima\Downloads\students_clean.csv")
print(df_cvs)
# Out:
#     StudentID       Name Gender     City    JoinDate  Math  Science  English
# 0           1      Aditi      M    Delhi  2024-01-10  95.0     63.0     98.0
# 1           2      Rohan      F  Chennai  2024-01-19  62.0     77.0     77.0
# 2           3      Meera      F  Chennai  2024-01-28  45.0     76.0     61.0
# 3           4      Karan      M   Mumbai  2024-02-06  66.6     65.0     61.0
# 4           5      Sneha      M    Delhi  2024-02-15  75.0     89.0     61.0
# 5           6      Arjun      F  Kolkata  2024-02-24  79.0     71.0     87.0
# 6           7      Priya      M     Pune  2024-03-04  41.0     40.0     55.0
# 7           8     Vikram      F  Kolkata  2024-03-13  54.0     83.0     45.0
# 8           9     Anjali      M  Chennai  2024-03-22  84.0     66.2     56.0
# 9          10      Rahul      M  Chennai  2024-03-31  88.0     75.0     36.0
# 10         11      Divya      F  Chennai  2024-04-09  62.0     71.0     41.0
# ...

# %%
# print(df_cvs.groupby('City')['Math().round(2)'])

# %%
# report * df_csv.groupby('City')agg(
#     total_math=('Math','sum'),
#     avg_math('Math' , 'mean'),
#     students=('Math','count')
# )

# %%
print(
    df_cvs.groupby(['City', 'Gender'])['Math']
          .agg(['count', 'min', 'max', 'median', 'std'])
          .round(2)
)
# Out:
#                 count   min   max  median    std
# City    Gender
# Chennai F           6  42.0  75.0    62.0  12.83
#         M           5  43.0  88.0    52.0  21.46
# Delhi   F           4  53.0  86.0    64.5  13.78
#         M           4  66.6  95.0    79.5  12.19
# Kolkata F           4  35.0  88.0    66.5  24.10
#         M           1  84.0  84.0    84.0    NaN
# Mumbai  F           5  37.0  88.0    77.0  24.17
#         M           2  66.6  86.0    76.3  13.72
# Pune    F           4  50.0  92.0    72.0  20.17
#         M           5  41.0  71.0    66.6  13.46

# %%
customers = pd.read_csv(r"C:\Users\dhima\Downloads\customers.csv")
order = pd.read_csv(r"C:\Users\dhima\Downloads\orders.csv")
print(customers)
print(order)
# Out:
#    CustID          Name     City
# 0     101    Ananya Rao    Delhi
# 1     102    Bilal Khan   Mumbai
# 2     103   Chitra Iyer     Pune
# 3     104  Dev Malhotra  Chennai
# 4     105   Esha Kapoor  Kolkata
# 5     106  Faisal Ahmed    Delhi
#    OrderID  CustID     Product  Amount   OrderDate
# 0     1001     101      Laptop   55000  2026-01-05
# 1     1002     102  Headphones    2500  2026-01-08
# 2     1003     102     Monitor    9800  2026-01-15
# 3     1004     104    Keyboard    1200  2026-02-02
# 4     1005     107      Webcam    3200  2026-02-10
# 5     1006     101       Mouse     700  2026-02-14
# 6     1007     108      Tablet   21000  2026-03-01

# %%
jan = orders[orders[r"C:\Users\dhima\Downloads\orders.csv"] < '2026-02-01']
feb = orders[orders[r"C:\Users\dhima\Downloads\orders.csv"] >= '2026-02-01']
all_
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[20], line 1
# ----> 1 jan = orders[orders[r"C:\Users\dhima\Downloads\orders.csv"] < '2026-02-01']
#       2 feb = orders[orders[r"C:\Users\dhima\Downloads\orders.csv"] >= '2026-02-01']
#       3 all_
#
# NameError: name 'orders' is not defined

# %%
sales = pd.read_csv(r"C:\Users\dhima\Downloads\sales.csv")
print(sales['OrderDate'].dtype)
sales['OrderData'] = pd.to_datetime(sales['OrderDate'])
print(sales['OrderDate'].dtype)
# Out:
# str
# str

# %%
sales['Year']  = sales['OrderDate'].dt.Year
sales['Month'] = sales['OrderDate'].dt.Month
print(sales[['OrderDate' , 'Year' , 'Month']].head(2))
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# Cell In[27], line 1
# ----> 1 sales['Year']  = sales['OrderDate'].dt.Year
#       2 sales['Month'] = sales['OrderDate'].dt.Month
#       3 print(sales[['OrderDate' , 'Year' , 'Month']].head(2))
#
# File ~\AppData\Local\Packages\PythonSoftwareFoundation.Python.3.12_qbz5n2kfra8p0\LocalCache\local-packages\Python312\site-packages\pandas\core\generic.py:6206, in NDFrame.__getattr__(self, name)
#    6202             and name not in self._accessors
#    6203             and self._info_axis._can_hold_identifiers_and_holds_name(name)
#    6204         ):
#    6205             return self[name]
# -> 6206         return object.__getattribute__(self, name)
#
# ...
