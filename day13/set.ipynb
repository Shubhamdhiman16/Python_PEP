# %%
s = {}
print(type(s))
# Out:
# <class 'dict'>

# %%
A = {10 , 20 , 30}
print(len(A) , min(A) , max(A) , sum(A) , sorted(A) , any(A) , all(A) , enumerate(A))
# Out:
# 3 10 30 60 [10, 20, 30] True True <enumerate object at 0x000001F8AB7768E0>

# %%
s = {10,20,30}
s.add(40)
s.update([50,60])
print(s)
# Out:
# {40, 10, 50, 20, 60, 30}

# %%
s = {10,20,30}
s.remove(20)
s.discard(30)
print(s)
# Out:
# {10}

# %%
s = {10,20,30}
print(s.pop())
s.clear()
print(s)
# Out:
# 10
# set()

# %%
a = {1,2,3,4}
b = {3,4,5,6}
print(a|b)
print(a&b)
print(a-b)
print(a^b)
# Out:
# {1, 2, 3, 4, 5, 6}
# {3, 4}
# {1, 2}
# {1, 2, 5, 6}

# %%
a = {1,2,3,4}
b = {3,4,5,6}
print(a^b)
print(a&b)
print()
# Out:
# {1, 2, 5, 6}
# {3, 4}

# %%
cities = {"Delhi", "Mumbai", "Delhi", "Jaipur", "Mumbai", "Pune"}

print("Unique Cities:", cities)
# Out:
# Unique Cities: {'Jaipur', 'Delhi', 'Pune', 'Mumbai'}
