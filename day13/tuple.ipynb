# %%
items = ()

for i in range(5):
    value = input("Enter a string: ")
    items += (value,)

for i in range(len(items)):
    print(i, ":", items[i])
# Out:
# 0 : 2 ,3,4,5,5
# 1 :
# 2 :
# 3 : asd ,dwe,ew,ewe,ee
# 4 : dfdf,sdsd,dasd,sdsd,,sds

# %%
items = ()

for i in range(5):
    value = input("Enter a string: ")
    items += (value,)

for i in range(len(items)-1, -1, -1):
    print(i, ":", items[i])
# Out:
# 4 : kiwi
# 3 : orange
# 2 : apple
# 1 : bananan
# 0 : mango
