# %%
a = 10;
if(a == 10):
    print("a is 10");
else:
    print("a is not 10");
# Out:
# a is 10

# %%
salary = int(input("Enter a number: "));

if salary < 50000:
    print("Awarded with phone");
elif salary < 100000:
    print("Awarded with laptop");
else:
    print("Awarded with Macbook Pro + iPhone");
# Out:
# Awarded with Macbook Pro + iPhone

# %%
order = int(input("Enter your order number: "));
if order == 1000:
    print("discount 10%");
elif order == 2000:
    print("discount 20%");
elif order == 3000:
    print("discount 30%");
else:
    print("discount 0%");
