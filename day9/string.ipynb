# %%
name = input("Enter your city: ")

print(name[0 : 3])
# Out:
# kan

# %%
name = input("Enter your name: ")

print("First Character:", name[0])
print("Last Character:", name[-1])
print("Length:", len(name))
# Out:
# First Character: S
# Last Character: m
# Length: 7

# %%
collage = input("enter a number: ")
print("collage name: " ,collage[-3 : -1])
# Out:
# collage name:  it

# %%
email = "dhimanshubham1221@gmail.com"
print( email[0 : 5])
# Out:
# dhima
